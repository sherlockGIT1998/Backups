# %%
#  Importing all important Libraries

import pandas as pd

import numpy as np

import seaborn as sns

import matplotlib as plt

import warnings

warnings.filterwarnings('ignore')

from IPython import display

pd.set_option('display.max_columns',None)

pd.set_option('display.max_rows',None)

# %% [markdown]
# ## Data Collection :

# %%
df = pd.read_csv('cars-dataset (2).csv')
df.head()
# Out:
#    Unnamed: 0                          Model  Serie Company  \
# 0           0             AC Ace (1993-1996)    Ace      AC
# 1           1           AC Aceca (1998-2000)  Aceca      AC
# 2           2           AC Aceca (1998-2000)  Aceca      AC
# 3           3     AC Cobra MkIII (1965-1967)  Cobra      AC
# 4           4  AC Cobra 378 MkIV (1965-1967)  Cobra      AC
#
#                                           Body style                 Segment  \
# 0  Convertible (spider/spyder, cabrio/cabriolet, ...            Coupe Cabrio
# 1                                   Coupé (two-door)                   Coupe
# 2                                   Coupé (two-door)                   Coupe
# 3                                   Coupé (two-door)  Roadster & Convertible
# 4                                   Coupé (two-door)  Roadster & Convertible
#
#          Production years Cylinders Displacement          Power(HP)  \
# 0  1993, 1994, 1995, 1996        V8     4942 cm3  260 HP @ 5250 RPM
# ...

# %% [markdown]
# ## Data Preprocessing :

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29792 entries, 0 to 29791
# Data columns (total 56 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Unnamed: 0                         29792 non-null  int64
#  1   Model                              29792 non-null  object
#  2   Serie                              29792 non-null  object
#  3   Company                            29792 non-null  object
#  4   Body style                         22238 non-null  object
#  5   Segment                            29792 non-null  object
#  6   Production years                   29792 non-null  object
#  7   Cylinders                          29270 non-null  object
#  8   Displacement                       28796 non-null  object
#  9   Power(HP)                          29226 non-null  object
#  10  Power(BHP)                         29226 non-null  object
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0
# count  29792.000000
# mean   14895.500000
# std     8600.353946
# min        0.000000
# 25%     7447.750000
# 50%    14895.500000
# 75%    22343.250000
# max    29791.000000

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=29792, step=1),
#  Index(['Unnamed: 0', 'Model', 'Serie', 'Company', 'Body style', 'Segment',
#         'Production years', 'Cylinders', 'Displacement', 'Power(HP)',
#         'Power(BHP)', 'Power(KW)', 'Torque(lb-ft)', 'Torque(Nm)',
#         'Electrical motor power', 'Electrical motor torque', 'Fuel System',
#         'Fuel', 'Fuel capacity', 'Top Speed',
#         'Acceleration 0-62 Mph (0-100 kph)', 'Drive Type', 'Gearbox',
#         'Front brake', 'Rear brake', 'Tire Size', 'Length', 'Width', 'Height',
#         'Front/rear Track', 'Wheelbase', 'Ground Clearance',
#         'Aerodynamics (Cd)', 'Aerodynamics (frontal area)', 'Turning circle',
#         'Cargo Volume', 'Unladen Weight', 'Gross Weight Limit', 'Combined mpg',
#         'City mpg', 'Highway mpg', 'CO2 Emissions', 'CO2 Emissions (Combined)',
#         'Turning circle (curb to curb)', 'Total maximum power', 'Power pack',
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=29792, step=1)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Model', 'Serie', 'Company', 'Body style', 'Segment',
#        'Production years', 'Cylinders', 'Displacement', 'Power(HP)',
#        'Power(BHP)', 'Power(KW)', 'Torque(lb-ft)', 'Torque(Nm)',
#        'Electrical motor power', 'Electrical motor torque', 'Fuel System',
#        'Fuel', 'Fuel capacity', 'Top Speed',
#        'Acceleration 0-62 Mph (0-100 kph)', 'Drive Type', 'Gearbox',
#        'Front brake', 'Rear brake', 'Tire Size', 'Length', 'Width', 'Height',
#        'Front/rear Track', 'Wheelbase', 'Ground Clearance',
#        'Aerodynamics (Cd)', 'Aerodynamics (frontal area)', 'Turning circle',
#        'Cargo Volume', 'Unladen Weight', 'Gross Weight Limit', 'Combined mpg',
#        'City mpg', 'Highway mpg', 'CO2 Emissions', 'CO2 Emissions (Combined)',
#        'Turning circle (curb to curb)', 'Total maximum power', 'Power pack',
#        'Nominal Capacity', 'Top speed (electrical)', 'EV Range', 'High mpg',
# ...

# %%
df.nunique()
# Out:
# Unnamed: 0                           29792
# Model                                 7044
# Serie                                 2733
# Company                                124
# Body style                               7
# Segment                                 28
# Production years                       843
# Cylinders                               62
# Displacement                          1304
# Power(HP)                             5334
# Power(BHP)                            5153
# Power(KW)                             6283
# Torque(lb-ft)                         5822
# Torque(Nm)                            6193
# Electrical motor power                 180
# Electrical motor torque                118
# Fuel System                            321
# Fuel                                    12
# Fuel capacity                          148
# Top Speed                              527
# Acceleration 0-62 Mph (0-100 kph)      284
# Drive Type                               3
# ...

# %%
df.shape
# Out:
# (29792, 56)

# %%
df.dtypes
# Out:
# Unnamed: 0                            int64
# Model                                object
# Serie                                object
# Company                              object
# Body style                           object
# Segment                              object
# Production years                     object
# Cylinders                            object
# Displacement                         object
# Power(HP)                            object
# Power(BHP)                           object
# Power(KW)                            object
# Torque(lb-ft)                        object
# Torque(Nm)                           object
# Electrical motor power               object
# Electrical motor torque              object
# Fuel System                          object
# Fuel                                 object
# Fuel capacity                        object
# Top Speed                            object
# Acceleration 0-62 Mph (0-100 kph)    object
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0                               0
# Model                                    0
# Serie                                    0
# Company                                  0
# Body style                            7554
# Segment                                  0
# Production years                         0
# Cylinders                              522
# Displacement                           996
# Power(HP)                              566
# Power(BHP)                             566
# Power(KW)                              566
# Torque(lb-ft)                         1072
# Torque(Nm)                            1072
# Electrical motor power               29059
# Electrical motor torque              29271
# Fuel System                            212
# Fuel                                    65
# Fuel capacity                         8199
# Top Speed                             4433
# Acceleration 0-62 Mph (0-100 kph)     5125
# Drive Type                             165
# ...

# %%
df.fillna(10000000,inplace = True)

# %%
df.isna().sum()
# Out:
# Unnamed: 0                           0
# Model                                0
# Serie                                0
# Company                              0
# Body style                           0
# Segment                              0
# Production years                     0
# Cylinders                            0
# Displacement                         0
# Power(HP)                            0
# Power(BHP)                           0
# Power(KW)                            0
# Torque(lb-ft)                        0
# Torque(Nm)                           0
# Electrical motor power               0
# Electrical motor torque              0
# Fuel System                          0
# Fuel                                 0
# Fuel capacity                        0
# Top Speed                            0
# Acceleration 0-62 Mph (0-100 kph)    0
# Drive Type                           0
# Gearbox                              0
# Front brake                          0
# ...

# %% [markdown]
# ## Data Visualization :

# %%
sns.boxplot(df['Unnamed: 0'])

# %%
sns.countplot(df['Unnamed: 0'])

# %%
sns.pairplot(df)

# %% [markdown]
# ## Compairing Numerical Features with Categorical Features :

# %%
df.select_dtypes(include = 'object').head()
# Out:
#                            Model  Serie Company  \
# 0             AC Ace (1993-1996)    Ace      AC
# 1           AC Aceca (1998-2000)  Aceca      AC
# 2           AC Aceca (1998-2000)  Aceca      AC
# 3     AC Cobra MkIII (1965-1967)  Cobra      AC
# 4  AC Cobra 378 MkIV (1965-1967)  Cobra      AC
#
#                                           Body style                 Segment  \
# 0  Convertible (spider/spyder, cabrio/cabriolet, ...            Coupe Cabrio
# 1                                   Coupé (two-door)                   Coupe
# 2                                   Coupé (two-door)                   Coupe
# 3                                   Coupé (two-door)  Roadster & Convertible
# 4                                   Coupé (two-door)  Roadster & Convertible
#
#          Production years Cylinders Displacement          Power(HP)  \
# 0  1993, 1994, 1995, 1996        V8     4942 cm3  260 HP @ 5250 RPM
# 1        1998, 1999, 2000        V8     3506 cm3  350 HP @ 6500 RPM
# ...

# %%
df.select_dtypes(exclude = 'object').head()
# Out:
#    Unnamed: 0
# 0           0
# 1           1
# 2           2
# 3           3
# 4           4

# %% [markdown]
# ## Using groupby :

# %%
df.groupby('Body style').first().head()
# Out:
#                                                     Unnamed: 0  \
# Body style
# 10000000                                                    34
# Convertible (spider/spyder, cabrio/cabriolet, d...           0
# Coupé (two-door)                                             1
# Hatchback                                                  171
# SUV (Sports Utility Vehicle)                                10
#
#                                                                                    Model  \
# Body style
# 10000000                                                        ACURA TLX (2020-Present)
# Convertible (spider/spyder, cabrio/cabriolet, d...                    AC Ace (1993-1996)
# Coupé (two-door)                                                    AC Aceca (1998-2000)
# Hatchback                                           ALFA ROMEO Giulia GTA (2020-Present)
# SUV (Sports Utility Vehicle)                                    ACURA MDX (2021-Present)
#
# ...

# %% [markdown]
# ## Compairing two Features :

# %%
pd.crosstab(df['Serie'],df['Company']).T.head()
# Out:
# Serie       "Wedge Series"  1  1 Series  1 Series 3 doors  1 Series Cabriolet  \
# Company
# AC                       0  0         0                 0                   0
# ACURA                    0  0         0                 0                   0
# ALFA ROMEO               0  0         0                 0                   0
# ALPINE                   0  0         0                 0                   0
# ARIEL                    0  0         0                 0                   0
#
# Serie       1 Series Coupe  1 Series M Coupe  1 Series Sedan  10 Series  \
# Company
# AC                       0                 0               0          0
# ACURA                    0                 0               0          0
# ALFA ROMEO               0                 0               0          0
# ALPINE                   0                 0               0          0
# ARIEL                    0                 0               0          0
#
# ...

# %% [markdown]
# ## Handling Outliers :

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Model', 'Serie', 'Company', 'Body style', 'Segment',
#        'Production years', 'Cylinders', 'Displacement', 'Power(HP)',
#        'Power(BHP)', 'Power(KW)', 'Torque(lb-ft)', 'Torque(Nm)',
#        'Electrical motor power', 'Electrical motor torque', 'Fuel System',
#        'Fuel', 'Fuel capacity', 'Top Speed',
#        'Acceleration 0-62 Mph (0-100 kph)', 'Drive Type', 'Gearbox',
#        'Front brake', 'Rear brake', 'Tire Size', 'Length', 'Width', 'Height',
#        'Front/rear Track', 'Wheelbase', 'Ground Clearance',
#        'Aerodynamics (Cd)', 'Aerodynamics (frontal area)', 'Turning circle',
#        'Cargo Volume', 'Unladen Weight', 'Gross Weight Limit', 'Combined mpg',
#        'City mpg', 'Highway mpg', 'CO2 Emissions', 'CO2 Emissions (Combined)',
#        'Turning circle (curb to curb)', 'Total maximum power', 'Power pack',
#        'Nominal Capacity', 'Top speed (electrical)', 'EV Range', 'High mpg',
# ...

# %%
sns.boxplot(df['Top Sp'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 sns.boxplot(df['Top Speed'])
#
# File G:\anaconda\lib\site-packages\seaborn\categorical.py:2231, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2224 def boxplot(
#    2225     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    2226     orient=None, color=None, palette=None, saturation=.75, width=.8,
#    2227     dodge=True, fliersize=5, linewidth=None, whis=1.5, ax=None,
#    2228     **kwargs
#    2229 ):
# -> 2231     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2232                           orient, color, palette, saturation,
#    2233                           width, dodge, fliersize, linewidth)
#    2235     if ax is None:
#    2236         ax = plt.gca()
#
# ...

# %% [markdown]
# ## Linearity :

# %%
import matplotlib
import seaborn
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.dtypes
# Out:
# Unnamed: 0                            int64
# Model                                object
# Serie                                object
# Company                              object
# Body style                           object
# Segment                              object
# Production years                     object
# Cylinders                            object
# Displacement                         object
# Power(HP)                            object
# Power(BHP)                           object
# Power(KW)                            object
# Torque(lb-ft)                        object
# Torque(Nm)                           object
# Electrical motor power               object
# Electrical motor torque              object
# Fuel System                          object
# Fuel                                 object
# Fuel capacity                        object
# Top Speed                            object
# Acceleration 0-62 Mph (0-100 kph)    object
# ...

# %%
df.head()
# Out:
#    Unnamed: 0                          Model  Serie Company  \
# 0           0             AC Ace (1993-1996)    Ace      AC
# 1           1           AC Aceca (1998-2000)  Aceca      AC
# 2           2           AC Aceca (1998-2000)  Aceca      AC
# 3           3     AC Cobra MkIII (1965-1967)  Cobra      AC
# 4           4  AC Cobra 378 MkIV (1965-1967)  Cobra      AC
#
#                                           Body style                 Segment  \
# 0  Convertible (spider/spyder, cabrio/cabriolet, ...            Coupe Cabrio
# 1                                   Coupé (two-door)                   Coupe
# 2                                   Coupé (two-door)                   Coupe
# 3                                   Coupé (two-door)  Roadster & Convertible
# 4                                   Coupé (two-door)  Roadster & Convertible
#
#          Production years Cylinders Displacement          Power(HP)  \
# 0  1993, 1994, 1995, 1996        V8     4942 cm3  260 HP @ 5250 RPM
# ...

# %%
r = df.corr()
r
# Out:
#             Unnamed: 0
# Unnamed: 0         1.0

# %%
plt.figure(figsize = (3,10))
sns.heatmap(r,annot = True)

# %% [markdown]
# ## Multicollinearity :

# %%
df1 = df.drop('Unnamed: 0',axis = 1)
df1.head()
# Out:
#                            Model  Serie Company  \
# 0             AC Ace (1993-1996)    Ace      AC
# 1           AC Aceca (1998-2000)  Aceca      AC
# 2           AC Aceca (1998-2000)  Aceca      AC
# 3     AC Cobra MkIII (1965-1967)  Cobra      AC
# 4  AC Cobra 378 MkIV (1965-1967)  Cobra      AC
#
#                                           Body style                 Segment  \
# 0  Convertible (spider/spyder, cabrio/cabriolet, ...            Coupe Cabrio
# 1                                   Coupé (two-door)                   Coupe
# 2                                   Coupé (two-door)                   Coupe
# 3                                   Coupé (two-door)  Roadster & Convertible
# 4                                   Coupé (two-door)  Roadster & Convertible
#
#          Production years Cylinders Displacement          Power(HP)  \
# 0  1993, 1994, 1995, 1996        V8     4942 cm3  260 HP @ 5250 RPM
# 1        1998, 1999, 2000        V8     3506 cm3  350 HP @ 6500 RPM
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif_list = []
for i in range(df.shape[1]) :
    vif = variance_inflation_factor(df,i)
    vif_list.append(vif)
    print(vif_list)

# %% [markdown]
# ## Model Building :

# %%
from sklearn.linear_model import LinearRegression

# %%
x = df.drop('Unnamed: 0',axis = 1)
y = df['Unnamed: 0']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size =0.2 , random_state=42)

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)

# %%
y_pred = model.predict(x_test)

# %%
y_pred_train = model.predict(x_train)
